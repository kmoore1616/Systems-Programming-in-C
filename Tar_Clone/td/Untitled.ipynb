# %%
13-61
# Out:
# -48

# %%
101-48
# Out:
# 53

# %%
-48%101
# Out:
# 53

# %%
(1/3)%101
# Out:
# 34

# %%
o(x) = (((x-3)*(x-5))/((1-3)*(1-5)))
r(x) = (((x-1)*(x-5))/((3-1)*(3-5)))
v(x) = (((x-1)*(x-3))/((5-1)*(5-3)))
p(x) = o(x)*8 + r(x)*10+v(x)*11
x = p(0)
print(mod(x, 17))
# Out:
# 13

# %%
mod(3^11, 13)
# Out:
# 9

# %%
2^3
# Out:
# 8

# %%
657.str(2)
# Out:
# '1010010001'

# %%
657-512
# Out:
# 145

# %%
2^7
# Out:
# 128

# %%
2^4
# Out:
# 16

# %%
2^9
# Out:
# 512

# %%
(305*126*182*3)%659
# Out:
# 220

# %%
c = matrix(IntegerModRing(26), [[2, 1], [5,3]])
e = matrix(IntegerModRing(26), [[8, 22], [21,11], [22,4]])
e*c^-1
# Out:
# [18 10]
# [ 8  1]
# [20 12]

# %%
mod(15^24,26)
# Out:
# 1

# %%
93-88
# Out:
# 5

# %%
(101-88*3)%26
# Out:
# 19

# %%
f(x) = x*3+91
x=f(121)
print(mod(x, 127))
# Out:
# 73
